# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img("Base data/Training/Happy/download.jpg")

# %%
plt.imshow(img)

# %%
cv2.imread("Base data/Training/Happy/download.jpg")
# Out:
# array([[[149, 158, 167],
#         [149, 158, 167],
#         [149, 158, 167],
#         ...,
#         [141, 151, 161],
#         [140, 150, 160],
#         [140, 150, 160]],
#
#        [[149, 158, 167],
#         [149, 158, 167],
#         [150, 159, 168],
#         ...,
#         [141, 151, 161],
#         [141, 151, 161],
#         [140, 150, 160]],
#
#        [[149, 158, 167],
#         [149, 158, 167],
#         [150, 159, 168],
#         ...,
#         [142, 152, 162],
#         [141, 151, 161],
#         [141, 151, 161]],
#
#        ...,
#
#        [[168, 107,  11],
#         [179, 119,  23],
#         [174, 119,  22],
#         ...,
#         [175, 122,  18],
#         [172, 119,  15],
#         [168, 116,  10]],
#
#        [[173, 110,  18],
#         [184, 123,  27],
#         [175, 117,  14],
#         ...,
#         [171, 119,  13],
#         [175, 123,  17],
#         [170, 118,  12]],
#
#        [[197, 131,  42],
#         [162,  98,   3],
#         [169, 112,   3],
#         ...,
#         [171, 116,  11],
#         [169, 117,  11],
#         [177, 125,  18]]], dtype=uint8)

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)

# %%
train_dataset = train.flow_from_directory("Base data/Training/",
                                         target_size = (200,200),
                                         batch_size = 3,
                                         class_mode = 'binary')
# Out:
# Found 30 images belonging to 2 classes.

# %%
validation_dataset = train.flow_from_directory("Base data/Validation/",
                                         target_size = (200,200),
                                         batch_size = 3,
                                         class_mode = 'binary')
# Out:
# Found 13 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape = (200,200,3)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(loss = 'binary_crossentropy',
             optimizer = tf.keras.optimizers.RMSprop(lr=0.001),
             metrics=['accuracy'])

# %%
model_fit = model.fit(train_dataset ,
                     steps_per_epoch = 3,
                     epochs = 30,
                     validation_data = validation_dataset)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 2s 457ms/step - loss: 11.3542 - accuracy: 0.6667 - val_loss: 2.5820 - val_accuracy: 0.3846
# Epoch 2/30
# 3/3 [==============================] - 1s 336ms/step - loss: 6.5826e-05 - accuracy: 1.0000 - val_loss: 2.6569 - val_accuracy: 0.3846
# Epoch 3/30
# 3/3 [==============================] - 1s 307ms/step - loss: 3.0108e-04 - accuracy: 1.0000 - val_loss: 2.6253 - val_accuracy: 0.3846
# Epoch 4/30
# 3/3 [==============================] - 1s 298ms/step - loss: 6.8913e-04 - accuracy: 1.0000 - val_loss: 2.9160 - val_accuracy: 0.3846
# Epoch 5/30
# 3/3 [==============================] - 1s 289ms/step - loss: 1.8608e-05 - accuracy: 1.0000 - val_loss: 2.9227 - val_accuracy: 0.3846
# Epoch 6/30
# 3/3 [==============================] - 1s 303ms/step - loss: 7.3066e-05 - accuracy: 1.0000 - val_loss: 3.1762 - val_accuracy: 0.3846
# Epoch 7/30
# 3/3 [==============================] - 1s 292ms/step - loss: 1.7181e-05 - accuracy: 1.0000 - val_loss: 3.1769 - val_accuracy: 0.3846
# Epoch 8/30
# 3/3 [==============================] - 1s 292ms/step - loss: 3.1549e-05 - accuracy: 1.0000 - val_loss: 3.2810 - val_accuracy: 0.4615
# Epoch 9/30
# 3/3 [==============================] - 1s 286ms/step - loss: 2.3065e-05 - accuracy: 1.0000 - val_loss: 3.2866 - val_accuracy: 0.4615
# Epoch 10/30
# 3/3 [==============================] - 1s 285ms/step - loss: 2.1559e-05 - accuracy: 1.0000 - val_loss: 3.3039 - val_accuracy: 0.4615
# Epoch 11/30
# 3/3 [==============================] - 1s 286ms/step - loss: 6.1351e-06 - accuracy: 1.0000 - val_loss: 3.3231 - val_accuracy: 0.4615
# Epoch 12/30
# 3/3 [==============================] - 1s 297ms/step - loss: 2.2963e-05 - accuracy: 1.0000 - val_loss: 3.1934 - val_accuracy: 0.3846
# Epoch 13/30
# 3/3 [==============================] - 1s 288ms/step - loss: 1.3967e-05 - accuracy: 1.0000 - val_loss: 3.2876 - val_accuracy: 0.3846
# Epoch 14/30
# 3/3 [==============================] - 1s 279ms/step - loss: 8.0219e-06 - accuracy: 1.0000 - val_loss: 3.3402 - val_accuracy: 0.4615
# Epoch 15/30
# 3/3 [==============================] - 1s 291ms/step - loss: 9.3477e-06 - accuracy: 1.0000 - val_loss: 3.3925 - val_accuracy: 0.4615
# Epoch 16/30
# 3/3 [==============================] - 1s 288ms/step - loss: 1.2413e-05 - accuracy: 1.0000 - val_loss: 3.3357 - val_accuracy: 0.3846
# Epoch 17/30
# 3/3 [==============================] - 1s 293ms/step - loss: 7.3000e-06 - accuracy: 1.0000 - val_loss: 3.4734 - val_accuracy: 0.4615
# Epoch 18/30
# 3/3 [==============================] - 1s 292ms/step - loss: 5.4261e-06 - accuracy: 1.0000 - val_loss: 3.5458 - val_accuracy: 0.4615
# Epoch 19/30
# 3/3 [==============================] - 1s 287ms/step - loss: 7.9834e-06 - accuracy: 1.0000 - val_loss: 3.5549 - val_accuracy: 0.4615
# Epoch 20/30
# 3/3 [==============================] - 1s 290ms/step - loss: 4.2955e-06 - accuracy: 1.0000 - val_loss: 3.5766 - val_accuracy: 0.4615
# Epoch 21/30
# 3/3 [==============================] - 1s 288ms/step - loss: 5.8128e-06 - accuracy: 1.0000 - val_loss: 3.5057 - val_accuracy: 0.4615
# Epoch 22/30
# 3/3 [==============================] - 1s 289ms/step - loss: 4.7424e-06 - accuracy: 1.0000 - val_loss: 3.4148 - val_accuracy: 0.3846
# Epoch 23/30
# 3/3 [==============================] - 1s 295ms/step - loss: 1.8853e-06 - accuracy: 1.0000 - val_loss: 3.4203 - val_accuracy: 0.3846
# Epoch 24/30
# 3/3 [==============================] - 1s 295ms/step - loss: 2.8400e-06 - accuracy: 1.0000 - val_loss: 3.5259 - val_accuracy: 0.4615
# Epoch 25/30
# 3/3 [==============================] - 1s 292ms/step - loss: 6.9437e-06 - accuracy: 1.0000 - val_loss: 3.4800 - val_accuracy: 0.3846
# Epoch 26/30
# 3/3 [==============================] - 1s 299ms/step - loss: 3.3244e-06 - accuracy: 1.0000 - val_loss: 3.4232 - val_accuracy: 0.3846
# Epoch 27/30
# 3/3 [==============================] - 1s 295ms/step - loss: 3.6479e-06 - accuracy: 1.0000 - val_loss: 3.4238 - val_accuracy: 0.3846
# Epoch 28/30
# 3/3 [==============================] - 1s 289ms/step - loss: 5.6545e-06 - accuracy: 1.0000 - val_loss: 3.4350 - val_accuracy: 0.3846
# Epoch 29/30
# 3/3 [==============================] - 1s 287ms/step - loss: 1.0846e-06 - accuracy: 1.0000 - val_loss: 3.4725 - val_accuracy: 0.3846
# Epoch 30/30
# 3/3 [==============================] - 1s 297ms/step - loss: 1.1994e-06 - accuracy: 1.0000 - val_loss: 3.4998 - val_accuracy: 0.3846

# %%
dir_path = "Base Data/Testing"

for i in os.listdir(dir_path):
    img = image.load_img(dir_path+"/"+i , target_size=(200,200,3))
    plt.imshow(img)
    plt.show()
    
    X = image.img_to_array(img)
    X = np.expand_dims(X,axis=0)
    images = np.vstack([X])
    
    val = model.predict(images)
    if val == 0:
        print("Not happy")
    else:
        print("happy")
# Out:
# 1/1 [==============================] - 0s 128ms/step
# Not happy
# 1/1 [==============================] - 0s 43ms/step
# happy
# 1/1 [==============================] - 0s 42ms/step
# happy
# 1/1 [==============================] - 0s 49ms/step
# happy
# 1/1 [==============================] - 0s 48ms/step
# Not happy
# 1/1 [==============================] - 0s 43ms/step
# happy
# 1/1 [==============================] - 0s 45ms/step
# happy
# 1/1 [==============================] - 0s 58ms/step
# Not happy

# %% [markdown]
# From the above results, the model correctly predicted 6 images out of 8. So the model's accuracy is 6/8 * 100 = 75%
